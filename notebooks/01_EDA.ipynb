# %%
import pandas as pd

# Load the dataset
file_path = '../data/alzheimers_prediction_dataset.csv'
df = pd.read_csv(file_path)

# Display the first 5 rows and the shape of the dataset
print(f"Dataset Shape: {df.shape}")
df.head()
# Out:
# Dataset Shape: (74283, 25)
#         Country  Age  Gender  Education Level   BMI Physical Activity Level  \
# 0         Spain   90    Male                1  33.0                  Medium
# 1     Argentina   72    Male                7  29.9                  Medium
# 2  South Africa   86  Female               19  22.9                    High
# 3         China   53    Male               17  31.2                     Low
# 4        Sweden   58  Female                3  30.0                    High
#
#   Smoking Status Alcohol Consumption Diabetes Hypertension  ...  \
# 0          Never        Occasionally       No           No  ...
# 1         Former               Never       No           No  ...
# 2        Current        Occasionally       No          Yes  ...
# 3          Never           Regularly      Yes           No  ...
# 4         Former               Never      Yes           No  ...
#
#   Dietary Habits Air Pollution Exposure  Employment Status Marital Status  \
# 0        Healthy                   High            Retired         Single
# 1        Healthy                 Medium         Unemployed        Widowed
# 2        Average                 Medium           Employed         Single
# 3        Healthy                 Medium            Retired         Single
# 4      Unhealthy                   High           Employed        Married
#
#   Genetic Risk Factor (APOE-ε4 allele) Social Engagement Level Income Level  \
# 0                                   No                     Low       Medium
# 1                                   No                    High          Low
# 2                                   No                     Low       Medium
# 3                                   No                    High       Medium
# 4                                   No                     Low       Medium
#
#   Stress Levels Urban vs Rural Living Alzheimer’s Diagnosis
# 0          High                 Urban                    No
# 1          High                 Urban                    No
# 2          High                 Rural                    No
# 3           Low                 Rural                    No
# 4          High                 Rural                    No
#
# [5 rows x 25 columns]

# %%
# 1. Check basic information and data types
print("--- Dataset Info ---")
df.info()

# 2. Check for missing values in each column
print("\n--- Missing Values ---")
print(df.isnull().sum())

# 3. Check the balance of our target variable
print("\n--- Target Variable Distribution ---")
print(df['Alzheimer’s Diagnosis'].value_counts())
# Out:
# --- Dataset Info ---
# <class 'pandas.DataFrame'>
# RangeIndex: 74283 entries, 0 to 74282
# Data columns (total 25 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Country                               74283 non-null  str
#  1   Age                                   74283 non-null  int64
#  2   Gender                                74283 non-null  str
#  3   Education Level                       74283 non-null  int64
#  4   BMI                                   74283 non-null  float64
#  5   Physical Activity Level               74283 non-null  str
#  6   Smoking Status                        74283 non-null  str
#  7   Alcohol Consumption                   74283 non-null  str
#  8   Diabetes                              74283 non-null  str
#  9   Hypertension                          74283 non-null  str
#  10  Cholesterol Level                     74283 non-null  str
#  11  Family History of Alzheimer’s         74283 non-null  str
#  12  Cognitive Test Score                  74283 non-null  int64
#  13  Depression Level                      74283 non-null  str
#  14  Sleep Quality                         74283 non-null  str
#  15  Dietary Habits                        74283 non-null  str
#  16  Air Pollution Exposure                74283 non-null  str
#  17  Employment Status                     74283 non-null  str
#  18  Marital Status                        74283 non-null  str
#  19  Genetic Risk Factor (APOE-ε4 allele)  74283 non-null  str
#  20  Social Engagement Level               74283 non-null  str
#  21  Income Level                          74283 non-null  str
#  22  Stress Levels                         74283 non-null  str
#  23  Urban vs Rural Living                 74283 non-null  str
#  24  Alzheimer’s Diagnosis                 74283 non-null  str
# dtypes: float64(1), int64(3), str(21)
# memory usage: 14.2 MB
#
# --- Missing Values ---
# Country                                 0
# Age                                     0
# Gender                                  0
# Education Level                         0
# BMI                                     0
# Physical Activity Level                 0
# Smoking Status                          0
# Alcohol Consumption                     0
# Diabetes                                0
# Hypertension                            0
# Cholesterol Level                       0
# Family History of Alzheimer’s           0
# Cognitive Test Score                    0
# Depression Level                        0
# Sleep Quality                           0
# Dietary Habits                          0
# Air Pollution Exposure                  0
# Employment Status                       0
# Marital Status                          0
# Genetic Risk Factor (APOE-ε4 allele)    0
# Social Engagement Level                 0
# Income Level                            0
# Stress Levels                           0
# Urban vs Rural Living                   0
# Alzheimer’s Diagnosis                   0
# dtype: int64
#
# --- Target Variable Distribution ---
# Alzheimer’s Diagnosis
# No     43570
# Yes    30713
# Name: count, dtype: int64
